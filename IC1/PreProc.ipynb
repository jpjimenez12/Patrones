# %% [markdown]
# # Mushroom Data Set

# %% [markdown]
# http://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Se Procede a cargar el archivo

# %%
mushroom = pd.read_csv("agaricus-lepiota.data")

# %% [markdown]
# Se visualiza las primeras lineas

# %%
mushroom.head()
# Out:
#    p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0  e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1  e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2  p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3  e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4  e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
#
# [5 rows x 23 columns]

# %% [markdown]
# El data set presenta varios problemas, por lo que se procede primero a definir los atributos correspondientes.

# %%
column_names = ["Classes", "Cap Shape", "Cap Surface", "Cap Color", "Bruises?", "Odor", "Gill Attachment", "Gill Spacing", "Gill Size", "Gill Color", "Stalk Shape", "Stalk Root", "Stalk Surface Above Ring", "Stalk Surface Below Ring", "Stalk Color Above Ring", "Stalk Color Below Ring", "Veil Type", "Veil Color", "Ring Number", "Ring Type", "Spore Print Color", "Population", "Habitat"]

# %%
mushroom = pd.read_csv("agaricus-lepiota.data", names = column_names)

# %% [markdown]
# Ahora se muestra cada columna con el Atributo correspondiente.

# %%
mushroom.head()
# Out:
#   Classes Cap Shape Cap Surface Cap Color Bruises? Odor Gill Attachment  \
# 0       p         x           s         n        t    p               f
# 1       e         x           s         y        t    a               f
# 2       e         b           s         w        t    l               f
# 3       p         x           y         w        t    p               f
# 4       e         x           s         g        f    n               f
#
#   Gill Spacing Gill Size Gill Color  ... Stalk Surface Below Ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   Stalk Color Above Ring Stalk Color Below Ring Veil Type Veil Color  \
# ...

# %% [markdown]
# Se procede a sustituir las letras con un valor numerico para un mejor tratamiento de los datos.

# %% [markdown]
# * Clases
#     - 0 -> Edible    (e)
#     - 1 -> Poisonous (p)
# * Cap Shape
#     - 0 -> Bell    (b)
#     - 1 -> Conical (c)
#     - 2 -> Convex  (x)
#     - 3 -> Flat    (f)
#     - 4 -> Knobbed (k)
#     - 5 -> Sunken  (s)
# * Cap Surface
#     - 0 -> Fibrous (f)
#     - 1 -> Grooves (g)
#     - 2 -> Scaly   (y)
#     - 3 -> Smooth  (s)
# * Cap Color
#     - 0 -> Brown    (n)
#     - 1 -> Buff     (b)
#     - 2 -> Cinnamon (c)
#     - 3 -> Gray     (g)
#     - 4 -> Green    (r)
#     - 5 -> Pink     (p)
#     - 6 -> Purple   (u)
#     - 7 -> Red      (e)
#     - 8 -> White    (w)
#     - 9 -> Yellow   (y)
# * Bruises?
#     - 0 -> No  (f)
#     - 1 -> Yes (T)
# * Odor
#     - 0 -> None     (n)
#     - 1 -> Almond   (a)
#     - 2 -> Anise    (l)
#     - 3 -> Creosote (c)
#     - 4 -> Fishy    (y)
#     - 5 -> Foul     (f)
#     - 6 -> Musty    (m)
#     - 7 -> Pungent  (p)
#     - 8 -> Spicy    (s)
# * Gill Attachment
#     - 0 -> Notched    (n)
#     - 1 -> Attached   (a)
#     - 2 -> Descending (d)
#     - 3 -> Free       (f)
# * Gill Spacing
#     - 0 -> Close   (c)
#     - 1 -> Crowded (w)
#     - 2 -> Distant (d)
# * Gill Size
#     - 0 -> Narrow (n)
#     - 1 -> Broad  (b)
# * Gill Color
#     - 0  -> Black     (k)
#     - 1  -> Brown     (n)
#     - 2  -> Buff      (b)
#     - 3  -> Chocolate (h)
#     - 4  -> Gray      (g)
#     - 5  -> Green     (r)
#     - 6  -> Orange    (o)
#     - 7  -> Pink      (p)
#     - 8  -> Purple    (u)
#     - 9  -> Red       (e)
#     - 10 -> White     (w)
#     - 11 -> Yellow    (y)
# * Stalk Shape
#     - 0 -> Enlarging (e)
#     - 1 -> Tapering  (t)
# * Stalk Root
#     - 0   -> Bulbous     (b)
#     - 1   -> Club        (c)
#     - 2   -> Cup         (u)
#     - 3   -> Equal       (e)
#     - 4   -> Rhizomorphs (z)
#     - 5   -> Rooted      (r)
#     - NaN -> Missing     (?)
# * Stalk Surface Above Ring
#     - 0 -> Fibrous (f)
#     - 1 -> Scaly   (y)
#     - 2 -> Silky   (k)
#     - 3 -> Smooth  (s)
# * Stalk Surface Below Ring
#     - 0 -> Fibrous (f)
#     - 1 -> Scaly   (y)
#     - 2 -> Silky   (k)
#     - 3 -> Smooth  (s)
# * Stalk Color Above Ring
#     - 0 -> Brown     (n)
#     - 1 -> Buff      (b)
#     - 2 -> Cinnamon  (c)
#     - 3 -> Gray      (g)
#     - 4 -> Orange    (o)
#     - 5 -> Pink      (p)
#     - 6 -> Red       (e)
#     - 7 -> White     (w)
#     - 8 -> Yellow    (y)
# * Stalk Color Below Ring
#     - 0 -> Brown     (n)
#     - 1 -> Buff      (b)
#     - 2 -> Cinnamon  (c)
#     - 3 -> Gray      (g)
#     - 4 -> Orange    (o)
#     - 5 -> Pink      (p)
#     - 6 -> Red       (e)
#     - 7 -> White     (w)
#     - 8 -> Yellow    (y)
# * Veil Type
#     - 0 -> Partial   (p)
#     - 1 -> Universal (u)
# * Veil Color
#     - 0 -> Brown  (n)
#     - 1 -> Orange (o)
#     - 2 -> White  (w)
#     - 3 -> Yellow (y)
# * Ring Number
#     - 0 -> None (n)
#     - 1 -> One  (0)
#     - 2 -> Two  (t)
# * Ring Type
#     - 0 -> None       (n)
#     - 1 -> Cobwebby   (c)
#     - 2 -> Evanescent (e)
#     - 3 -> Flarting   (f)
#     - 4 -> Large      (l)
#     - 5 -> Pendant    (p)
#     - 6 -> Sheathing  (s)
#     - 7 -> Zone       (z)
# * Spore Print Color
#     - 0 -> Black     (k)
#     - 1 -> Brown     (n)
#     - 2 -> Buff      (b)
#     - 3 -> Chocolate (h)
#     - 4 -> Green     (r)
#     - 5 -> Orange    (o)
#     - 6 -> Purple    (u)
#     - 7 -> White     (w)
#     - 8 -> Yellow    (y)
# * Population
#     - 0 -> Abundant  (a)
#     - 1 -> Clustered (c)
#     - 2 -> Numerous  (n)
#     - 3 -> Scattered (s)
#     - 4 -> Several   (v)
#     - 5 -> Solitary  (y)
# * Habitad
#     - 0 -> Grasses (g)
#     - 1 -> Leaves  (l)
#     - 2 -> Meadows (m)
#     - 3 -> Path    (p)
#     - 4 -> urban   (u)
#     - 5 -> waste   (w)
#     - 6 -> Woods   (d)

# %%
mushroom["Classes"] = mushroom["Classes"].replace({"e" : "Edible", "p" : "Poisonous"})
mushroom["Cap Shape"] = mushroom["Cap Shape"].replace({"b": 0, "c" : 1, "x" : 2, "f" : 3, "k" : 4, "s" : 5})
mushroom["Cap Surface"] = mushroom["Cap Surface"].replace({"f" : 0, "g" : 1, "y" : 2, "s" : 3})
mushroom["Cap Color"] = mushroom["Cap Color"].replace({"n" : 0, "b" : 1, "c" : 2, "g" : 3, "r" : 4, "p" : 5, "u" : 6, "e" : 7, "w" : 8, "y" : 9})
mushroom["Bruises?"] = mushroom["Bruises?"].replace({"f" : 0, "t" : 1})
mushroom["Odor"] = mushroom["Odor"].replace({"n" : 0, "a" : 1, "l" : 2, "c" : 3, "y" : 4, "f" : 5, "m" : 6, "p" : 7, "s" : 8})
mushroom["Gill Attachment"] = mushroom["Gill Attachment"].replace({"n" : 0, "a" : 1, "d" : 2, "f": 3})
mushroom["Gill Spacing"] = mushroom["Gill Spacing"].replace({"c" : 0, "w" : 1, "d" : 2})
mushroom["Gill Size"] = mushroom["Gill Size"].replace({"n" : 0, "b" : 1})
mushroom["Gill Color"] = mushroom["Gill Color"].replace({"k" : 0, "n" : 1, "b" : 2, "h" : 3, "g" : 4, "r" : 5, "o" : 6, "p" : 7, "u" : 8, "e" : 9, "w" : 10, "y" : 11})
mushroom["Stalk Shape"] = mushroom["Stalk Shape"].replace({"e" : 0, "t" : 1})
mushroom["Stalk Root"] = mushroom["Stalk Root"].replace({"b" : 0, "c" : 1, "u" : 2, "e" : 3, "z" : 4, "r" : 5, "?" : np.nan})
mushroom["Stalk Surface Above Ring"] = mushroom["Stalk Surface Above Ring"].replace({"f" : 0, "y" : 1, "k" : 2, "s" : 3})
mushroom["Stalk Surface Below Ring"] = mushroom["Stalk Surface Below Ring"].replace({"f" : 0, "y" : 1, "k" : 2, "s" : 3})
mushroom["Stalk Color Above Ring"] = mushroom["Stalk Color Above Ring"].replace({"n" : 0, "b" : 1, "c" : 2, "g" : 3, "o" : 4, "p" : 5, "e" : 6, "w" : 7, "y" : 8})
mushroom["Stalk Color Below Ring"] = mushroom["Stalk Color Below Ring"].replace({"n" : 0, "b" : 1, "c" : 2, "g" : 3, "o" : 4, "p" : 5, "e" : 6, "w" : 7, "y" : 8})
mushroom["Veil Type"] = mushroom["Veil Type"].replace({"p" : 0, "u" : 1})
mushroom["Veil Color"] = mushroom["Veil Color"].replace({"n" : 0, "o" : 1, "w" : 2, "y" : 3})
mushroom["Ring Number"] = mushroom["Ring Number"].replace({"n" : 0, "o" : 1, "t" : 2})
mushroom["Ring Type"] = mushroom["Ring Type"].replace({"n" : 0, "c" : 1, "e" : 2, "f" : 3, "l" : 4, "p" : 5, "s" : 6, "z" : 7})
mushroom["Spore Print Color"] = mushroom["Spore Print Color"].replace({"k" : 0, "n" : 1, "b" : 2, "h" : 3, "r" : 4, "o" : 5, "u" : 6, "w" : 7, "y" : 8})
mushroom["Population"] = mushroom["Population"].replace({"a" : 0, "c" : 1, "n" : 2, "s" : 3, "v" : 4, "y" : 5})
mushroom["Habitat"] = mushroom["Habitat"].replace({"g" : 0, "l" : 1, "m" : 2, "p" : 3, "u" : 4, "w" : 5, "d" : 6})

# %%
mushroom.head()
# Out:
#      Classes  Cap Shape  Cap Surface  Cap Color  Bruises?  Odor  \
# 0  Poisonous          2            3          0         1     7
# 1     Edible          2            3          9         1     1
# 2     Edible          0            3          8         1     2
# 3  Poisonous          2            2          8         1     7
# 4     Edible          2            3          3         0     0
#
#    Gill Attachment  Gill Spacing  Gill Size  Gill Color  ...  \
# 0                3             0          0           0  ...
# 1                3             0          1           0  ...
# 2                3             0          1           1  ...
# 3                3             0          0           1  ...
# 4                3             1          1           0  ...
#
#    Stalk Surface Below Ring  Stalk Color Above Ring  Stalk Color Below Ring  \
# 0                         3                       7                       7
# ...

# %% [markdown]
# Ahora se cambiara el valor NaN que se muestran en la columna "Stalk Root" por la media de los valores de dicha columna.

# %%
mushroom["Stalk Root"].fillna(mushroom["Stalk Root"].mean(), inplace = True)

# %%
mushroom.head()
# Out:
#      Classes  Cap Shape  Cap Surface  Cap Color  Bruises?  Odor  \
# 0  Poisonous          2            3          0         1     7
# 1     Edible          2            3          9         1     1
# 2     Edible          0            3          8         1     2
# 3  Poisonous          2            2          8         1     7
# 4     Edible          2            3          3         0     0
#
#    Gill Attachment  Gill Spacing  Gill Size  Gill Color  ...  \
# 0                3             0          0           0  ...
# 1                3             0          1           0  ...
# 2                3             0          1           1  ...
# 3                3             0          0           1  ...
# 4                3             1          1           0  ...
#
#    Stalk Surface Below Ring  Stalk Color Above Ring  Stalk Color Below Ring  \
# 0                         3                       7                       7
# ...

# %%
mushroom["Stalk Root"] = mushroom["Stalk Root"].round()

# %%
plt.figure()
sns.countplot(x = "Odor", hue = "Classes", data = mushroom, palette = "RdBu")
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7, 8], ["None", "Almond", "Anise", "Creosote", "Fishy", "Foul", "Musty", "Pungent", "Spicy"])
plt.show()
